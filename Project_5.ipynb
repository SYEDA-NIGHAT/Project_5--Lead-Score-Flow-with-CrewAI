# %% [markdown]
# <a href="https://colab.research.google.com/github/SYEDA-NIGHAT/Project_5--Lead-Score-Flow-with-CrewAI/blob/main/Project_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 📝 Create the Outlining Task
outline_task = Task(
    description="Create an outline for a book titled 'The Future of AI'.",
    agent=outliner,
    expected_output="A structured book outline with chapter titles and short descriptions."  # ✅ Required field
)

# 📝 Create the Writing Task
writing_task = Task(
    description="Write a detailed chapter based on the book outline.",
    agent=writer,
    depends_on=[outline_task],
    expected_output="A well-written chapter with proper flow and coherence."  # ✅ Required field
)

# 📝 Create the Editing Task
editing_task = Task(
    description="Edit and refine the written chapter for clarity.",
    agent=editor,
    depends_on=[writing_task],
    expected_output="A polished chapter with improved grammar, readability, and logical structure."  # ✅ Required field
)

# %%
# !pip install google-generativeai crewai langchain python-dotenv litellm
